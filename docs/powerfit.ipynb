# %% [markdown]
# # Powerfit
#
# You can run powerfit by letting protein detetective print the commands
#
# This notebook requires the cells before powerfit in the [workflow notebook](workflow.ipynb#run-powerfit) to be executed.
#
# In this notebook we will run powerfit using API.

# %%
from pathlib import Path

from rich import print as pprint

from protein_detective.powerfit.options import PowerfitOptions

# %%
session_dir = Path("session1")
session_dir
# Out:
# PosixPath('session1')

# %%
options = PowerfitOptions(
    angle=20,
)
pprint(options)
# Out:
# PowerfitOptions(
#     angle=20,
#     no_laplace=False,
#     no_core_weighted=False,
#     no_resampling=False,
#     resampling_rate=2.0,
#     no_trimming=False,
#     trimming_cutoff=None,
#     cpu=False,
#     workers_per_gpu=1,
#     gpu_backend='opencl',
#     nproc=1,
#     batch_size=100
# )

# %%
from protein_detective.powerfit.workflow import powerfit_runs

# %% [markdown]
# To run you must have cloned the https://github.com/haddocking/powerfit-tutorial repository in '../../powerfit-tutorial'.

# %%
target = Path("../../powerfit-tutorial/ribosome-KsgA.map")

# %%
powerfit_run_id = powerfit_runs(target, 13, session_dir, options=options)
powerfit_run_id
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 powerfit_run_id = powerfit_runs(                                                             │
# │   2 │   target, 13,                                                                              │
# │   3 │   session_dir, options=options)                                                            │
# │   4 powerfit_run_id                                                                              │
# │                                                                                                  │
# │ /home/verhoes/git/protein-detective/protein-detective/src/protein_detective/powerfit/workflow.py │
# │ :189 in powerfit_runs                                                                            │
# │                                                                                                  │
# │   186 │   """                                                                                    │
# │   187 │   session_dir.mkdir(parents=True, exist_ok=True)                                         │
# │   188 │   start_time = datetime.now(tz=UTC)                                                      │
# │ ❱ 189 │   powerfit_run_id, powerfit_run_root_dir, density_map_target, structure_files = _initi   │
# │   190 │   │   session_dir, target, powerfit_run_id=powerfit_run_id                               │
# │   191 │   )                                                                                      │
# │   192 │   fittable_structures_csv: Path = session_dir / "powerfit" / "fittable_structures.csv"   │
# │                                                                                                  │
# │ /home/verhoes/git/protein-detective/protein-detective/src/protein_detective/powerfit/workflow.py │
# │ :67 in _initialize_powerfit_run                                                                  │
# │                                                                                                  │
# │    64 │   shutil.copy(density_map, density_map_target)                                           │
# │    65 │   logger.info(f"Copied density map from {density_map} to {density_map_target}")          │
# │    66 │                                                                                          │
# │ ❱  67 │   structure_files = _find_structure_files(session_dir)                                   │
# │    68 │                                                                                          │
# │    69 │   return powerfit_run_id, powerfit_run_dir, density_map_target, structure_files          │
# │    70                                                                                            │
# │                                                                                                  │
# │ /home/verhoes/git/protein-detective/protein-detective/src/protein_detective/powerfit/workflow.py │
# │ :42 in _find_structure_files                                                                     │
# │                                                                                                  │
# │    39 │   │   │   f"Structure files directory '{structure_files_dir}' does not exist. "          │
# │    40 │   │   │   "Please run `protein-detective filter` command."                               │
# │    41 │   │   )                                                                                  │
# │ ❱  42 │   │   raise FileNotFoundError(msg)                                                       │
# │    43 │   return sorted(structure_files_dir.glob("*"))                                           │
# │    44                                                                                            │
# │    45                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# FileNotFoundError: Structure files directory 'session1/combined_output' does not exist. Please run
# `protein-detective filter` command.

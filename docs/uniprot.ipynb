# %%
from protein_detective.uniprot import search, Query
from pprint import pprint

# %%
query = Query(
        taxon_id="9606",
        reviewed=True,
        subcellular_location_uniprot="nucleus",
        subcellular_location_go="GO:0005634", # Cellular component - Nucleus
        molecular_function_go="GO:0003677" # Molecular function - DNA binding
)

# %%
results = search(query, limit=200)
pprint(results)
# Out:
# Result(alphafold={'P04637', 'O14646'},
#        pdb={'O14646': {PdbResult(id='2B2V',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=268-443',
#                                  resolution='2.65'),
#                        PdbResult(id='2B2U',
#                                  method='X-Ray_Crystallography',
#                                  chain='C=268-373',
#                                  resolution='2.95'),
#                        PdbResult(id='4O42',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=216-230',
#                                  resolution='1.87'),
#                        PdbResult(id='2B2Y',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=268-443',
#                                  resolution='2.35'),
#                        PdbResult(id='2B2W',
#                                  method='X-Ray_Crystallography',
#                                  chain='D=2-20',
#                                  resolution='2.4'),
#                        PdbResult(id='2B2W',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=268-443',
#                                  resolution='2.4'),
#                        PdbResult(id='2B2W',
#                                  method='X-Ray_Crystallography',
#                                  chain='C=268-373',
#                                  resolution='2.4'),
#                        PdbResult(id='2B2Y',
#                                  method='X-Ray_Crystallography',
#                                  chain='C=268-373',
#                                  resolution='2.35'),
#                        PdbResult(id='2N39',
#                                  method='NMR_Spectroscopy',
#                                  chain='A=1409-1511',
#                                  resolution=None),
#                        PdbResult(id='2B2V',
#                                  method='X-Ray_Crystallography',
#                                  chain='C=268-373',
#                                  resolution='2.65'),
#                        PdbResult(id='4B4C',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1119-1327',
#                                  resolution='1.62'),
#                        PdbResult(id='5AFW',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=108-119',
#                                  resolution='1.6'),
#                        PdbResult(id='5AFW',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=270-443',
#                                  resolution='1.6'),
#                        PdbResult(id='8UMG',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B/C=268-445',
#                                  resolution='3.1'),
#                        PdbResult(id='2B2T',
#                                  method='X-Ray_Crystallography',
#                                  chain='D=2-20',
#                                  resolution='2.45'),
#                        PdbResult(id='4NW2',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/C=268-443',
#                                  resolution='1.9'),
#                        PdbResult(id='4O42',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=268-443',
#                                  resolution='1.87'),
#                        PdbResult(id='2B2U',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=268-443',
#                                  resolution='2.95'),
#                        PdbResult(id='2B2U',
#                                  method='X-Ray_Crystallography',
#                                  chain='D=2-16',
#                                  resolution='2.95'),
#                        PdbResult(id='2B2T',
#                                  method='X-Ray_Crystallography',
#                                  chain='C=268-373',
#                                  resolution='2.45'),
#                        PdbResult(id='4NW2',
#                                  method='X-Ray_Crystallography',
#                                  chain='B/D=216-230',
#                                  resolution='1.9'),
#                        PdbResult(id='2B2T',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=268-443',
#                                  resolution='2.45'),
#                        PdbResult(id='2B2V',
#                                  method='X-Ray_Crystallography',
#                                  chain='D=2-16',
#                                  resolution='2.65')},
#             'P04637': {PdbResult(id='6W51',
#                                  method='X-Ray_Crystallography',
#                                  chain='C/F/I/L=168-176',
#                                  resolution='3.53'),
#                        PdbResult(id='6W51',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/D/G/J=25-300',
#                                  resolution='3.53'),
#                        PdbResult(id='7RM4',
#                                  method='X-Ray_Crystallography',
#                                  chain='B/G/L/Q=21-119',
#                                  resolution='3.33'),
#                        PdbResult(id='7RM4',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/F/K/P=25-299',
#                                  resolution='3.33'),
#                        PdbResult(id='7RM4',
#                                  method='X-Ray_Crystallography',
#                                  chain='C/H/M/R=168-176',
#                                  resolution='3.33'),
#                        PdbResult(id='8OXM',
#                                  method='Electron_Microscopy',
#                                  chain='A/B=1-3056',
#                                  resolution='3.3'),
#                        PdbResult(id='8OXM',
#                                  method='Electron_Microscopy',
#                                  chain='E/F=11-22',
#                                  resolution='3.3'),
#                        PdbResult(id='8OXO',
#                                  method='Electron_Microscopy',
#                                  chain='A/B=1-3056',
#                                  resolution='3'),
#                        PdbResult(id='8OXO',
#                                  method='Electron_Microscopy',
#                                  chain='E/F=11-22',
#                                  resolution='3'),
#                        PdbResult(id='8HLL',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=10-35',
#                                  resolution='2.62'),
#                        PdbResult(id='8HLL',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=92-203',
#                                  resolution='2.62'),
#                        PdbResult(id='8HLL',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=95-290',
#                                  resolution='2.62'),
#                        PdbResult(id='8HLM',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=10-35',
#                                  resolution='2.52'),
#                        PdbResult(id='8HLM',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=92-203',
#                                  resolution='2.52'),
#                        PdbResult(id='8HLM',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=95-290',
#                                  resolution='2.52'),
#                        PdbResult(id='8HLN',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=10-35',
#                                  resolution='2.35'),
#                        PdbResult(id='8HLN',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=92-203',
#                                  resolution='2.35'),
#                        PdbResult(id='8HLN',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=95-290',
#                                  resolution='2.35'),
#                        PdbResult(id='6LHD',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=2-201',
#                                  resolution='2.5'),
#                        PdbResult(id='6LHD',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=96-292',
#                                  resolution='2.5'),
#                        PdbResult(id='8XP5',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=2-201',
#                                  resolution='2.55'),
#                        PdbResult(id='8XP5',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=95-292',
#                                  resolution='2.55'),
#                        PdbResult(id='7DVD',
#                                  method='X-Ray_Crystallography',
#                                  chain='E=136-150',
#                                  resolution='2.59'),
#                        PdbResult(id='7DVD',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B/C/D=92-290',
#                                  resolution='2.59'),
#                        PdbResult(id='1H26',
#                                  method='X-Ray_Crystallography',
#                                  chain='B/D=174-432',
#                                  resolution='2.24'),
#                        PdbResult(id='1H26',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/C=1-298',
#                                  resolution='2.24'),
#                        PdbResult(id='1H26',
#                                  method='X-Ray_Crystallography',
#                                  chain='E=376-386',
#                                  resolution='2.24'),
#                        PdbResult(id='2YDR',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=31-618',
#                                  resolution='2.75'),
#                        PdbResult(id='2YDR',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=144-154',
#                                  resolution='2.75'),
#                        PdbResult(id='7BWN',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/C/E/F/H/J/M/O=1-238',
#                                  resolution='2.4'),
#                        PdbResult(id='7BWN',
#                                  method='X-Ray_Crystallography',
#                                  chain='B/D/G/I/K/L/N/P=326-356',
#                                  resolution='2.4'),
#                        PdbResult(id='5XZC',
#                                  method='Electron_Microscopy',
#                                  chain='A=1046-1664',
#                                  resolution='10.7'),
#                        PdbResult(id='5XZC',
#                                  method='Electron_Microscopy',
#                                  chain='B/C/D/E=92-356',
#                                  resolution='10.7'),
#                        PdbResult(id='7XZX',
#                                  method='Electron_Microscopy',
#                                  chain='B/F=1-103',
#                                  resolution='4.53'),
#                        PdbResult(id='7XZX',
#                                  method='Electron_Microscopy',
#                                  chain='C/G=1-130',
#                                  resolution='4.53'),
#                        PdbResult(id='7XZX',
#                                  method='Electron_Microscopy',
#                                  chain='A/E=2-136',
#                                  resolution='4.53'),
#                        PdbResult(id='7XZX',
#                                  method='Electron_Microscopy',
#                                  chain='D/H=1-126',
#                                  resolution='4.53'),
#                        PdbResult(id='7XZX',
#                                  method='Electron_Microscopy',
#                                  chain='K/L/M/N=94-293',
#                                  resolution='4.53'),
#                        PdbResult(id='7XZZ',
#                                  method='Electron_Microscopy',
#                                  chain='B/F=1-103',
#                                  resolution='4.07'),
#                        PdbResult(id='7XZZ',
#                                  method='Electron_Microscopy',
#                                  chain='C/G=1-130',
#                                  resolution='4.07'),
#                        PdbResult(id='7XZZ',
#                                  method='Electron_Microscopy',
#                                  chain='A/E=2-136',
#                                  resolution='4.07'),
#                        PdbResult(id='7XZZ',
#                                  method='Electron_Microscopy',
#                                  chain='D/H=1-126',
#                                  resolution='4.07'),
#                        PdbResult(id='7XZZ',
#                                  method='Electron_Microscopy',
#                                  chain='K/L/M/N=1-393',
#                                  resolution='4.07'),
#                        PdbResult(id='6RZ3',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=625-828',
#                                  resolution='4.23'),
#                        PdbResult(id='6RZ3',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=62-292',
#                                  resolution='4.23'),
#                        PdbResult(id='3OQ5',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B/C=259-598',
#                                  resolution='2.5'),
#                        PdbResult(id='3OQ5',
#                                  method='X-Ray_Crystallography',
#                                  chain='D/E=377-386',
#                                  resolution='2.5'),
#                        PdbResult(id='1YCQ',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=13-119',
#                                  resolution='2.3'),
#                        PdbResult(id='1YCQ',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=13-29',
#                                  resolution='2.3'),
#                        PdbResult(id='1YCR',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=17-125',
#                                  resolution='2.6'),
#                        PdbResult(id='1YCR',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=15-29',
#                                  resolution='2.6'),
#                        PdbResult(id='4HFZ',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/C=17-125',
#                                  resolution='2.69'),
#                        PdbResult(id='4HFZ',
#                                  method='X-Ray_Crystallography',
#                                  chain='B/D=15-29',
#                                  resolution='2.69'),
#                        PdbResult(id='2L14',
#                                  method='NMR_Spectroscopy',
#                                  chain='A=2059-2117',
#                                  resolution=None),
#                        PdbResult(id='5HOU',
#                                  method='NMR_Spectroscopy',
#                                  chain='A=340-439',
#                                  resolution=None),
#                        PdbResult(id='5HP0',
#                                  method='NMR_Spectroscopy',
#                                  chain='A=1764-1857',
#                                  resolution=None),
#                        PdbResult(id='5HPD',
#                                  method='NMR_Spectroscopy',
#                                  chain='A=1764-1855',
#                                  resolution=None),
#                        PdbResult(id='6VRM',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=25-299',
#                                  resolution='2.61'),
#                        PdbResult(id='6VRN',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=21-119',
#                                  resolution='2.46'),
#                        PdbResult(id='6W51',
#                                  method='X-Ray_Crystallography',
#                                  chain='B/E/H/K=1-119',
#                                  resolution='3.53'),
#                        PdbResult(id='6VRN',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=168-176',
#                                  resolution='2.46'),
#                        PdbResult(id='6VRN',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=25-299',
#                                  resolution='2.46'),
#                        PdbResult(id='6R5L',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.88'),
#                        PdbResult(id='6RJZ',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.58'),
#                        PdbResult(id='6RJZ',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.58'),
#                        PdbResult(id='6VR5',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/D=25-299',
#                                  resolution='2.38'),
#                        PdbResult(id='6VRM',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=21-119',
#                                  resolution='2.61'),
#                        PdbResult(id='6VRM',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=168-176',
#                                  resolution='2.61'),
#                        PdbResult(id='6VR5',
#                                  method='X-Ray_Crystallography',
#                                  chain='P/Q=168-176',
#                                  resolution='2.38'),
#                        PdbResult(id='6VR1',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/D=25-299',
#                                  resolution='2.37'),
#                        PdbResult(id='6VR5',
#                                  method='X-Ray_Crystallography',
#                                  chain='B/E=21-119',
#                                  resolution='2.38'),
#                        PdbResult(id='6VR1',
#                                  method='X-Ray_Crystallography',
#                                  chain='P/Q=168-176',
#                                  resolution='2.37'),
#                        PdbResult(id='6VR1',
#                                  method='X-Ray_Crystallography',
#                                  chain='B/E=21-119',
#                                  resolution='2.37'),
#                        PdbResult(id='6VQO',
#                                  method='X-Ray_Crystallography',
#                                  chain='B/G=21-119',
#                                  resolution='3'),
#                        PdbResult(id='6VQO',
#                                  method='X-Ray_Crystallography',
#                                  chain='P/Q=168-176',
#                                  resolution='3'),
#                        PdbResult(id='6VQO',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/F=25-299',
#                                  resolution='3'),
#                        PdbResult(id='8R1G',
#                                  method='Electron_Microscopy',
#                                  chain='A/D=1-875',
#                                  resolution='3.99'),
#                        PdbResult(id='8R1G',
#                                  method='Electron_Microscopy',
#                                  chain='B/E=1-98',
#                                  resolution='3.99'),
#                        PdbResult(id='8R1G',
#                                  method='Electron_Microscopy',
#                                  chain='C/F=1-393',
#                                  resolution='3.99'),
#                        PdbResult(id='8R1G',
#                                  method='Electron_Microscopy',
#                                  chain='B/E=1-158',
#                                  resolution='3.99'),
#                        PdbResult(id='8R1F',
#                                  method='Electron_Microscopy',
#                                  chain='A=1-875',
#                                  resolution='3.67'),
#                        PdbResult(id='8R1F',
#                                  method='Electron_Microscopy',
#                                  chain='B=1-158',
#                                  resolution='3.67'),
#                        PdbResult(id='8R1F',
#                                  method='Electron_Microscopy',
#                                  chain='B=1-98',
#                                  resolution='3.67'),
#                        PdbResult(id='8R1F',
#                                  method='Electron_Microscopy',
#                                  chain='C=1-393',
#                                  resolution='3.67'),
#                        PdbResult(id='8GCR',
#                                  method='Electron_Microscopy',
#                                  chain='R=1-875',
#                                  resolution='3.38'),
#                        PdbResult(id='8GCR',
#                                  method='Electron_Microscopy',
#                                  chain='A=27-396',
#                                  resolution='3.38'),
#                        PdbResult(id='8GCR',
#                                  method='Electron_Microscopy',
#                                  chain='B=94-312',
#                                  resolution='3.38'),
#                        PdbResult(id='4XR8',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=406-417',
#                                  resolution='2.25'),
#                        PdbResult(id='8GCR',
#                                  method='Electron_Microscopy',
#                                  chain='A=1-158',
#                                  resolution='3.38'),
#                        PdbResult(id='4XR8',
#                                  method='X-Ray_Crystallography',
#                                  chain='F/H=8-158',
#                                  resolution='2.25'),
#                        PdbResult(id='4XR8',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=27-392',
#                                  resolution='2.25'),
#                        PdbResult(id='4XR8',
#                                  method='X-Ray_Crystallography',
#                                  chain='C/D=94-292',
#                                  resolution='2.25'),
#                        PdbResult(id='7NMI',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=1-95',
#                                  resolution='2.1'),
#                        PdbResult(id='7NMI',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=29-339',
#                                  resolution='2.1'),
#                        PdbResult(id='7NMI',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=17-56',
#                                  resolution='2.1'),
#                        PdbResult(id='4BV2',
#                                  method='X-Ray_Crystallography',
#                                  chain='E/H=376-388',
#                                  resolution='3.3'),
#                        PdbResult(id='4BV2',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=1-246',
#                                  resolution='3.3'),
#                        PdbResult(id='3PDH',
#                                  method='X-Ray_Crystallography',
#                                  chain='D=372-389',
#                                  resolution='1.8'),
#                        PdbResult(id='4BUZ',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-246',
#                                  resolution='1.9'),
#                        PdbResult(id='4BUZ',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=379-386',
#                                  resolution='1.9'),
#                        PdbResult(id='3PDH',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-246',
#                                  resolution='1.8'),
#                        PdbResult(id='1YCS',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=892-1126',
#                                  resolution='2.2'),
#                        PdbResult(id='2H59',
#                                  method='X-Ray_Crystallography',
#                                  chain='D/E=372-389',
#                                  resolution='1.9'),
#                        PdbResult(id='2H59',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=1-246',
#                                  resolution='1.9'),
#                        PdbResult(id='2H4J',
#                                  method='X-Ray_Crystallography',
#                                  chain='D=372-389',
#                                  resolution='2.1'),
#                        PdbResult(id='2H4H',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-246',
#                                  resolution='1.99'),
#                        PdbResult(id='2H4H',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=372-389',
#                                  resolution='1.99'),
#                        PdbResult(id='2H4J',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-246',
#                                  resolution='2.1'),
#                        PdbResult(id='2H4F',
#                                  method='X-Ray_Crystallography',
#                                  chain='D=372-389',
#                                  resolution='2'),
#                        PdbResult(id='2H2F',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=372-389',
#                                  resolution='2.2'),
#                        PdbResult(id='2H4F',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-246',
#                                  resolution='2'),
#                        PdbResult(id='2H2F',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-246',
#                                  resolution='2.2'),
#                        PdbResult(id='2H2D',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=372-389',
#                                  resolution='1.7'),
#                        PdbResult(id='1YC5',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-246',
#                                  resolution='1.4'),
#                        PdbResult(id='1YC5',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=372-389',
#                                  resolution='1.4'),
#                        PdbResult(id='2H2D',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-246',
#                                  resolution='1.7'),
#                        PdbResult(id='6RKI',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.88'),
#                        PdbResult(id='6RK8',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.6'),
#                        PdbResult(id='6RKI',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.88'),
#                        PdbResult(id='1YCS',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=94-292',
#                                  resolution='2.2'),
#                        PdbResult(id='6RK8',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.6'),
#                        PdbResult(id='2MEJ',
#                                  method='NMR_Spectroscopy',
#                                  chain='A=1-209',
#                                  resolution=None),
#                        PdbResult(id='7YGI',
#                                  method='X-Ray_Crystallography',
#                                  chain='C/D=23-145',
#                                  resolution='2.1'),
#                        PdbResult(id='2H1L',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B/C/D/E/F/G/H/I/J/K/L=260-627',
#                                  resolution='3.16'),
#                        PdbResult(id='2H1L',
#                                  method='X-Ray_Crystallography',
#                                  chain='M/N/O/P/Q/R/S/T/U/V/W/X=92-292',
#                                  resolution='3.16'),
#                        PdbResult(id='7YGI',
#                                  method='X-Ray_Crystallography',
#                                  chain='A/B=92-289',
#                                  resolution='2.1'),
#                        PdbResult(id='1MA3',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-253',
#                                  resolution='2'),
#                        PdbResult(id='1MA3',
#                                  method='X-Ray_Crystallography',
#                                  chain='B=372-389',
#                                  resolution='2'),
#                        PdbResult(id='6RKK',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.88'),
#                        PdbResult(id='6RKK',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.88'),
#                        PdbResult(id='6RKM',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.88'),
#                        PdbResult(id='6RL3',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.3'),
#                        PdbResult(id='6RKM',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.88'),
#                        PdbResult(id='6RL3',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.3'),
#                        PdbResult(id='6RL4',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.6'),
#                        PdbResult(id='6RL4',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.6'),
#                        PdbResult(id='6RL6',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.6'),
#                        PdbResult(id='6RL6',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.6'),
#                        PdbResult(id='6RM5',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.88'),
#                        PdbResult(id='6RM5',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.88'),
#                        PdbResult(id='6RM7',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.6'),
#                        PdbResult(id='6RM7',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.6'),
#                        PdbResult(id='6RWH',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.68'),
#                        PdbResult(id='6RWH',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.68'),
#                        PdbResult(id='6RWI',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.65'),
#                        PdbResult(id='6RWI',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.65'),
#                        PdbResult(id='6RWU',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.46'),
#                        PdbResult(id='6RWS',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.53'),
#                        PdbResult(id='6RWS',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.53'),
#                        PdbResult(id='6RWU',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.46'),
#                        PdbResult(id='6RX2',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.82'),
#                        PdbResult(id='6RX2',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.82'),
#                        PdbResult(id='6S39',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.88'),
#                        PdbResult(id='6S39',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.88'),
#                        PdbResult(id='6S3C',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='2'),
#                        PdbResult(id='6S3C',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='2'),
#                        PdbResult(id='6S40',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.9'),
#                        PdbResult(id='6S40',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.9'),
#                        PdbResult(id='6S9Q',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.69'),
#                        PdbResult(id='6S9Q',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.69'),
#                        PdbResult(id='6SIN',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-231',
#                                  resolution='1.64'),
#                        PdbResult(id='6SIN',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.64'),
#                        PdbResult(id='6SIO',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-231',
#                                  resolution='1.6'),
#                        PdbResult(id='6SIO',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.6'),
#                        PdbResult(id='6SIP',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-231',
#                                  resolution='1.6'),
#                        PdbResult(id='6SIP',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.6'),
#                        PdbResult(id='6SIQ',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-231',
#                                  resolution='1.6'),
#                        PdbResult(id='6SIQ',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.6'),
#                        PdbResult(id='6SLV',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-231',
#                                  resolution='1.9'),
#                        PdbResult(id='6SLV',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.9'),
#                        PdbResult(id='3LW1',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-248',
#                                  resolution='1.28'),
#                        PdbResult(id='3LW1',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=385-393',
#                                  resolution='1.28'),
#                        PdbResult(id='5MHC',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-231',
#                                  resolution='1.2'),
#                        PdbResult(id='5MHC',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.2'),
#                        PdbResult(id='5MOC',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-231',
#                                  resolution='1.8'),
#                        PdbResult(id='5MOC',
#                                  method='X-Ray_Crystallography',
#                                  chain='P=382-393',
#                                  resolution='1.8'),
#                        PdbResult(id='6R5L',
#                                  method='X-Ray_Crystallography',
#                                  chain='A=1-231',
#                                  resolution='1.88')}})
